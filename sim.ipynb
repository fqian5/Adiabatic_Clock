# %%
from clock import *
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Final Hamiltonian

# %%
X = np.array([[0,1],[1,0]])
Z = np.array([[1,0],[0,-1]])
I = np.eye(2)
zero_state_projector = 1/2*(I-Z)
H_hamiltonian_3 = ghz(3, X, Z, I)
H_hamiltonian_4 = ghz(4, X, Z, I)
H_hamiltonian_5 = ghz(5, X, Z, I)
H_hamiltonian_6 = ghz(6, X, Z, I)
H_hamiltonian_7 = ghz(7, X, Z, I)
H_hamiltonian_8 = ghz(8, X, Z, I)
H_hamiltonian_9 = ghz(9, X, Z, I)
H_hamiltonian_10 = ghz(10, X, Z, I)
H_hamiltonian_11 = ghz(11, X, Z, I)
# too big for n_qubits >11
# H_hamiltonian_12 = ghz(12, X, Z, I)
# H_hamiltonian_13 = ghz(13, X, Z, I)

# %%
H_hamiltonian_large_3 = (np.kron(zero_state_projector,np.eye(len(H_hamiltonian_3)*len(zero_state_projector))))+ (np.kron(np.eye(len(H_hamiltonian_3)*len(zero_state_projector)),zero_state_projector))+np.kron(np.kron(np.eye(len(zero_state_projector)),H_hamiltonian_3),np.eye(len(zero_state_projector))) # including the measurement qubit
H_hamiltonian_large_4 = (np.kron(zero_state_projector,np.eye(len(H_hamiltonian_4)*len(zero_state_projector))))+ (np.kron(np.eye(len(H_hamiltonian_4)*len(zero_state_projector)),zero_state_projector))+np.kron(np.kron(np.eye(len(zero_state_projector)),H_hamiltonian_4),np.eye(len(zero_state_projector))) # including the measurement qubit
H_hamiltonian_large_5 = (np.kron(zero_state_projector,np.eye(len(H_hamiltonian_5)*len(zero_state_projector))))+ (np.kron(np.eye(len(H_hamiltonian_5)*len(zero_state_projector)),zero_state_projector))+np.kron(np.kron(np.eye(len(zero_state_projector)),H_hamiltonian_5),np.eye(len(zero_state_projector))) # including the measurement qubit
H_hamiltonian_large_6 = (np.kron(zero_state_projector,np.eye(len(H_hamiltonian_6)*len(zero_state_projector))))+ (np.kron(np.eye(len(H_hamiltonian_6)*len(zero_state_projector)),zero_state_projector))+np.kron(np.kron(np.eye(len(zero_state_projector)),H_hamiltonian_6),np.eye(len(zero_state_projector))) # including the measurement qubit
H_hamiltonian_large_7 = (np.kron(zero_state_projector,np.eye(len(H_hamiltonian_7)*len(zero_state_projector))))+ (np.kron(np.eye(len(H_hamiltonian_7)*len(zero_state_projector)),zero_state_projector))+np.kron(np.kron(np.eye(len(zero_state_projector)),H_hamiltonian_7),np.eye(len(zero_state_projector))) # including the measurement qubit
H_hamiltonian_large_8 = (np.kron(zero_state_projector,np.eye(len(H_hamiltonian_8)*len(zero_state_projector))))+ (np.kron(np.eye(len(H_hamiltonian_8)*len(zero_state_projector)),zero_state_projector))+np.kron(np.kron(np.eye(len(zero_state_projector)),H_hamiltonian_8),np.eye(len(zero_state_projector))) # including the measurement qubit
H_hamiltonian_large_9 = (np.kron(zero_state_projector,np.eye(len(H_hamiltonian_9)*len(zero_state_projector))))+ (np.kron(np.eye(len(H_hamiltonian_9)*len(zero_state_projector)),zero_state_projector))+np.kron(np.kron(np.eye(len(zero_state_projector)),H_hamiltonian_9),np.eye(len(zero_state_projector))) # including the measurement qubit
H_hamiltonian_large_10 = (np.kron(zero_state_projector,np.eye(len(H_hamiltonian_10)*len(zero_state_projector))))+ (np.kron(np.eye(len(H_hamiltonian_10)*len(zero_state_projector)),zero_state_projector))+np.kron(np.kron(np.eye(len(zero_state_projector)),H_hamiltonian_10),np.eye(len(zero_state_projector))) # including the measurement qubit
H_hamiltonian_large_11 = (np.kron(zero_state_projector,np.eye(len(H_hamiltonian_11)*len(zero_state_projector))))+ (np.kron(np.eye(len(H_hamiltonian_11)*len(zero_state_projector)),zero_state_projector))+np.kron(np.kron(np.eye(len(zero_state_projector)),H_hamiltonian_11),np.eye(len(zero_state_projector))) # including the measurement qubit
# too big for n_qubits >11
# H_hamiltonian_large_12 = (np.kron

# %%
Hamiltonian_large_dict = {
    3: H_hamiltonian_large_3,
    4: H_hamiltonian_large_4,
    5: H_hamiltonian_large_5,
    6: H_hamiltonian_large_6,
    7: H_hamiltonian_large_7,
    8: H_hamiltonian_large_8,
    9: H_hamiltonian_large_9,
    10: H_hamiltonian_large_10,
    11: H_hamiltonian_large_11,
    # 12: H_hamiltonian_large_12, # too big for n_qubits >11
}

# %%
data_dict = {}

# %% [markdown]
# ### AA vs NOAA

# %%
for n_qubits in range(3,9):  
    post_selection_list = [0,n_qubits+1]
    min_gap_noaa =[]
    min_gap_aa =[]
    g_array = np.linspace(-1,-0.1,3)
    for g in g_array:
        new_state,unitaries_list = sequential_prep_unitary(g,n_qubits)
        U = np.array(product_unitaries_loop(unitaries_list[::-1]))
        unitaries_list = [U]
        # construct clock Ham
        clock_qubits = int(np.log2(len(unitaries_list)+1))
        H_clock = H_tot(unitaries_list).real
        H_final = np.kron(np.eye(2**clock_qubits),Hamiltonian_large_dict[n_qubits])+np.kron(plus_penalty(clock_qubits),np.eye(Hamiltonian_large_dict[n_qubits].shape[0]))
        if np.isclose(np.sum(H_final.imag.data), 0):
            H_final = H_final.real
        H_clock = scipy.sparse.dia_matrix(H_clock)
        H_final = scipy.sparse.dia_matrix(H_final)
        k = 5
        eigvals,eigvecs = scipy.sparse.linalg.eigsh(H_clock,k=k,which = 'SA')
        rescale_c = eigvals[1]-eigvals[0]
        eigvals1,eigvecs1 = scipy.sparse.linalg.eigsh(H_final,k=k,which = 'SA')
        rescale_f = eigvals1[1]-eigvals1[0]
        E0_list = []
        E1_list = []
        differece_noaa = []

        v_array = np.linspace(0,1,25)
        overlap = []
        for v in v_array:

            H_adia = v*H_final/rescale_f + (1-v)*H_clock/rescale_c

            evals,evecs=scipy.sparse.linalg.eigsh(H_adia,k=k,which = 'SA')
            diff = evals[1] - evals[0]
            differece_noaa.append(diff)
            overlap.append(np.dot(eigvecs1[:,0],evecs[:,0]))

        min_gap_noaa.append(min(differece_noaa))
        plt.plot(v_array, differece_noaa,label = 'g = '+str(g)+' noaa')  
        
        ###aa simulation
        U = aa(post_selection_list,U,1)@np.array(product_unitaries_loop(unitaries_list[::-1]))
        unitaries_list = [U]
        clock_qubits = int(np.log2(len(unitaries_list)+1))
        H_clock = H_tot(unitaries_list).real
        H_final = np.kron(np.eye(2**clock_qubits),Hamiltonian_large_dict[n_qubits])+np.kron(plus_penalty(clock_qubits),np.eye(Hamiltonian_large_dict[n_qubits].shape[0]))
        if np.isclose(np.sum(H_final.imag.data), 0):
            H_final = H_final.real

        H_clock = scipy.sparse.dia_matrix(H_clock)
        H_final = scipy.sparse.dia_matrix(H_final)
        k = 5
        eigvals,eigvecs = scipy.sparse.linalg.eigsh(H_clock,k=k,which = 'SA')
        rescale_c = eigvals[1]-eigvals[0]
        eigvals1,eigvecs1 = scipy.sparse.linalg.eigsh(H_final,k=k,which = 'SA')
        rescale_f = eigvals1[1]-eigvals1[0]
        E0_list = []
        E1_list = []
        differece_aa = []
        v_array = np.linspace(0,1,25)
        overlap = []
        for v in v_array:

            H_adia = v*H_final/rescale_f + (1-v)*H_clock/rescale_c
            evals,evecs=scipy.sparse.linalg.eigsh(H_adia,k=k,which = 'SA')
            diff = evals[1] - evals[0]
            differece_aa.append(diff)
            overlap.append(np.dot(eigvecs1[:,0],evecs[:,0]))
            gs = evecs[:,0]

        min_gap_aa.append(min(differece_aa))
        plt.plot(v_array, differece_aa,label = 'g = '+str(g)+' aa')  
        plt.xlabel('s')
        plt.ylabel('Gap') 
        plt.legend()
    data_dict['min_gap_noaa'+str(n_qubits)] = min_gap_noaa
    data_dict['min_gap_aa'+str(n_qubits)] = min_gap_aa
    plt.savefig('aa_vs_noaa'+str(n_qubits)+'_qubits.png')
    plt.show()
# Out:
# /Users/qianfeng/anaconda3/envs/clock/lib/python3.12/site-packages/scipy/sparse/_dia.py:75: SparseEfficiencyWarning: Constructing a DIA matrix with 127 diagonals is inefficient
#   A = self._coo_container(arg1, dtype=dtype, shape=shape).todia()
# /Users/qianfeng/anaconda3/envs/clock/lib/python3.12/site-packages/scipy/sparse/_dia.py:75: SparseEfficiencyWarning: Constructing a DIA matrix with 127 diagonals is inefficient
#   A = self._coo_container(arg1, dtype=dtype, shape=shape).todia()
# /Users/qianfeng/anaconda3/envs/clock/lib/python3.12/site-packages/scipy/sparse/_dia.py:75: SparseEfficiencyWarning: Constructing a DIA matrix with 127 diagonals is inefficient
#   A = self._coo_container(arg1, dtype=dtype, shape=shape).todia()
# /Users/qianfeng/anaconda3/envs/clock/lib/python3.12/site-packages/scipy/sparse/_dia.py:75: SparseEfficiencyWarning: Constructing a DIA matrix with 255 diagonals is inefficient
#   A = self._coo_container(arg1, dtype=dtype, shape=shape).todia()
# ...

# %%
data_dict.keys()
# Out:
# dict_keys(['min_gap_noaa3', 'min_gap_aa3', 'min_gap_noaa4', 'min_gap_aa4', 'min_gap_noaa5', 'min_gap_aa5', 'min_gap_noaa6', 'min_gap_aa6', 'min_gap_noaa7', 'min_gap_aa7', 'min_gap_noaa8', 'min_gap_aa8'])

# %%
aa_results = np.vstack([data_dict['min_gap_aa3'], data_dict['min_gap_aa4'], data_dict['min_gap_aa5'], data_dict['min_gap_aa6'], data_dict['min_gap_aa7'], data_dict['min_gap_aa8']])
noaa_results = np.vstack([data_dict['min_gap_noaa3'], data_dict['min_gap_noaa4'], data_dict['min_gap_noaa5'], data_dict['min_gap_noaa6'], data_dict['min_gap_noaa7'], data_dict['min_gap_noaa8']])

# %%
aa10 = aa_results[:,-1].flatten()
noaa10 = noaa_results[:,-1].flatten()
aa55 = aa_results[:,1].flatten()
noaa55 = noaa_results[:,1].flatten()
aa01 = aa_results[:,0].flatten()
noaa01 = noaa_results[:,0].flatten()

# %%
plt.plot(np.arange(3,9),aa10,label = 'aa g= -1.0')
plt.plot(np.arange(3,9),noaa10,label = 'noaa g= -1.0')
plt.plot(np.arange(3,9),aa55,label = 'aa g= -0.55')
plt.plot(np.arange(3,9),noaa55,label = 'noaa g= -0.55')
plt.plot(np.arange(3,9),aa01,label = 'aa g= -0.1')
plt.plot(np.arange(3,9),noaa01,label = 'noaa g= -0.1')
plt.xlabel('n_qubits')
plt.ylabel('Min Gap')
plt.legend()
plt.savefig('aa_vs_noaa_min_gap.png')
plt.show()
